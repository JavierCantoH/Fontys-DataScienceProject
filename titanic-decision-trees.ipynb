# %% [markdown]
# *ADS-A Week 6 Assignment*
#
# # Who Survived the Titanic Disaster?

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# In this titanic example we will use decision trees. The main advantage of this model is that humans can easily
# understand and reproduce the sequence of decisions taken to predict the target class of a new data point.
#
# This is very important for tasks such as medical diagnosis or credit approval, where we want to show a reason for the
# decision, rather than just saying this is what the training data suggests (which is, by definition, what every supervised
# learning method does).
#
# The problem we would like to solve is to determine if a Titanic's passenger would have survived, given age, passenger class,
# and sex. Why these features?
#
# Answer: Very specific features (name is an extreme case) could result in overfitting (consider a tree that just asks if the name is X, she survived). Features for which there are a small number of instances with each value present a similar problem. They might not be useful for generalization. We will use class, age, and sex because a priori, we expect them to have possibly influenced the passenger's survival.

# %% [markdown]
# Each instance in the dataset has the following form:
#
#      "1","1st",1,"Allen, Miss Elisabeth Walton",29.0000,"Southampton","St Louis, MO","B-5","24160 L221","2","female"
#
# Note that the raw data consists largely of strings. To apply machine learning algo's these strings have to be converted to numerical data first (at least the columns that are of interest)!

# %% [markdown]
# ## 2. Prepare Dataset with Pandas

# %% [markdown]
# Pandas is a Python module that works with the so-called dataframe concept (rows are observations, columns refer to the features). A dataframe is essentially a two-dimensional labeled data structure where
# each column represent a feature and each row represents an observation.
#
# More details, see: https://www.kaggle.com/c/titanic/details/getting-started-with-python-ii

# %% [markdown]
# ### 2.1. Load Dataset

# %% [markdown]
# Download the Titanic dataset (csv file) from Canvas, read it with Pandas into a dataframe. Show the first 5 rows.

# %%
import pandas as pd
import numpy as np

print('numpy version:', np.__version__)
print('matplotlib version:', pd.__version__)

## Your code ...
df_titanic = pd.read_csv("Titanic.csv")
df_titanic.columns =['passengers','pclass','survived','name','age','embarked','home/dest','room','ticket','boat','sex']
df_titanic.head(10)
# Out:
# numpy version: 1.23.3
# matplotlib version: 1.5.0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 8
#       5 print('matplotlib version:', pd.__version__)
#       7 ## Your code ...
# ----> 8 df_titanic = pd.read_csv("Titanic.csv")
#       9 df_titanic.columns =['passengers','pclass','survived','name','age','embarked','home/dest','room','ticket','boat','sex']
#      10 df_titanic.head(10)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1729, in TextFileReader._make_engine(self, f, engine)
#    1727     is_text = False
#    1728     mode = "rb"
# -> 1729 self.handles = get_handle(
#    1730     f,
#    1731     mode,
#    1732     encoding=self.options.get("encoding", None),
#    1733     compression=self.options.get("compression", None),
#    1734     memory_map=self.options.get("memory_map", False),
#    1735     is_text=is_text,
#    1736     errors=self.options.get("encoding_errors", "strict"),
#    1737     storage_options=self.options.get("storage_options", None),
#    1738 )
#    1739 assert self.handles is not None
#    1740 f = self.handles.handle
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/common.py:857, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     852 elif isinstance(handle, str):
#     853     # Check whether the filename is to be opened in binary mode.
#     854     # Binary mode does not support 'encoding' and 'newline'.
#     855     if ioargs.encoding and "b" not in ioargs.mode:
#     856         # Encoding
# --> 857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#     860             encoding=ioargs.encoding,
#     861             errors=errors,
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
#     866         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Titanic.csv'

# %% [markdown]
# Also show the 10 last rows. What is the problem in the last couple of rows?

# %%
## Your code ...
df_titanic.tail(10)
# Out:
#       passengers pclass  survived                    name  age embarked  \
# 1303        1304    3rd         0      Yasbeck, Mr Antoni  NaN      NaN
# 1304        1305    3rd         1     Yasbeck, Mrs Antoni  NaN      NaN
# 1305        1306    3rd         0      Youssef, Mr Gerios  NaN      NaN
# 1306        1307    3rd         0     Zabour, Miss Hileni  NaN      NaN
# 1307        1308    3rd         0     Zabour, Miss Tamini  NaN      NaN
# 1308        1309    3rd         0      Zakarian, Mr Artun  NaN      NaN
# 1309        1310    3rd         0  Zakarian, Mr Maprieder  NaN      NaN
# 1310        1311    3rd         0         Zenn, Mr Philip  NaN      NaN
# 1311        1312    3rd         0           Zievens, Rene  NaN      NaN
# 1312        1313    3rd         0          Zimmerman, Leo  NaN      NaN
#
#      home/dest room ticket boat     sex
# 1303       NaN  NaN    NaN  NaN    male
# 1304       NaN  NaN    NaN  NaN  female
# 1305       NaN  NaN    NaN  NaN    male
# 1306       NaN  NaN    NaN  NaN  female
# 1307       NaN  NaN    NaN  NaN  female
# 1308       NaN  NaN    NaN  NaN    male
# 1309       NaN  NaN    NaN  NaN    male
# 1310       NaN  NaN    NaN  NaN    male
# 1311       NaN  NaN    NaN  NaN  female
# 1312       NaN  NaN    NaN  NaN    male

# %% [markdown]
# ### 2.2. Investigate Dataset

# %% [markdown]
# How does Pandas interpret the data? The following 3 commands can be used to investigate the data. Describe in your own words what the command does.

# %%
df_titanic.dtypes

## Your answer ...
# Out:
# passengers      int64
# pclass         object
# survived        int64
# name           object
# age           float64
# embarked       object
# home/dest      object
# room           object
# ticket         object
# boat           object
# sex            object
# dtype: object

# %%
df_titanic.info()

## Your answer ...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 11 columns):
# passengers    1313 non-null int64
# pclass        1313 non-null object
# survived      1313 non-null int64
# name          1313 non-null object
# age           633 non-null float64
# embarked      821 non-null object
# home/dest     754 non-null object
# room          77 non-null object
# ticket        69 non-null object
# boat          347 non-null object
# sex           1313 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 112.9+ KB

# %%
df_titanic.describe()

## Your answer ...
# Out:
#         passengers     survived         age
# count  1313.000000  1313.000000  633.000000
# mean    657.000000     0.341965   31.194181
# std     379.174762     0.474549   14.747525
# min       1.000000     0.000000    0.166700
# 25%     329.000000     0.000000   21.000000
# 50%     657.000000     0.000000   30.000000
# 75%     985.000000     1.000000   41.000000
# max    1313.000000     1.000000   71.000000

# %%
# Slice the first 10 rows of the 'age' column. 

## Your code ...
df_titanic.loc[:10]
# Out:
#     passengers pclass  survived  \
# 0            1    1st         1
# 1            2    1st         0
# 2            3    1st         0
# 3            4    1st         0
# 4            5    1st         1
# 5            6    1st         1
# 6            7    1st         1
# 7            8    1st         0
# 8            9    1st         1
# 9           10    1st         0
# 10          11    1st         0
#
#                                                name      age     embarked  \
# 0                      Allen, Miss Elisabeth Walton  29.0000  Southampton
# 1                       Allison, Miss Helen Loraine   2.0000  Southampton
# 2               Allison, Mr Hudson Joshua Creighton  30.0000  Southampton
# 3   Allison, Mrs Hudson J.C. (Bessie Waldo Daniels)  25.0000  Southampton
# 4                     Allison, Master Hudson Trevor   0.9167  Southampton
# 5                                Anderson, Mr Harry  47.0000  Southampton
# 6                  Andrews, Miss Kornelia Theodosia  63.0000  Southampton
# 7                            Andrews, Mr Thomas, jr  39.0000  Southampton
# 8      Appleton, Mrs Edward Dale (Charlotte Lamson)  58.0000  Southampton
# 9                            Artagaveytia, Mr Ramon  71.0000    Cherbourg
# 10                        Astor, Colonel John Jacob  47.0000    Cherbourg
#
#                           home/dest   room             ticket  boat     sex
# 0                      St Louis, MO    B-5         24160 L221     2  female
# 1   Montreal, PQ / Chesterville, ON    C26                NaN   NaN  female
# 2   Montreal, PQ / Chesterville, ON    C26                NaN  -135    male
# 3   Montreal, PQ / Chesterville, ON    C26                NaN   NaN  female
# 4   Montreal, PQ / Chesterville, ON    C22                NaN    11    male
# 5                      New York, NY   E-12                NaN     3    male
# 6                        Hudson, NY    D-7          13502 L77    10  female
# 7                       Belfast, NI   A-36                NaN   NaN    male
# 8               Bayside, Queens, NY  C-101                NaN     2  female
# 9               Montevideo, Uruguay    NaN                NaN   -22    male
# 10                     New York, NY    NaN  17754 L224 10s 6d  -124    male

# %%
# What kind of object is this 'age' column?   
type(df_titanic['age'])

# Note: Single column is neither an numpy array, nor a pandas dataframe but rather a pandas-specific object called 
# data Series.
# Out:
# pandas.core.series.Series

# %%
# What is the average age over all passengers?

## Your code ...
average = df_titanic['age'].mean()
average
# Out:
# 31.19418104265403

# %%
# The next thing we'd like to do is look at more specific subsets of the dataframe. Slice the columns 'sex', 'pclass', 
# and 'age'.

## Your code ...
df_titanic[['sex','pclass','age']].head(10)
# Out:
#       sex pclass      age
# 0  female    1st  29.0000
# 1  female    1st   2.0000
# 2    male    1st  30.0000
# 3  female    1st  25.0000
# 4    male    1st   0.9167
# 5    male    1st  47.0000
# 6  female    1st  63.0000
# 7    male    1st  39.0000
# 8  female    1st  58.0000
# 9    male    1st  71.0000

# %%
# First look at all of the missing 'age' values, because we will need to address them in our model if we hope to use 
# all the data for more advanced algorithms. To filter for missing values you can use:
df_titanic[df_titanic['age'].isnull()][['sex', 'pclass', 'age']]

# Here the only thing we did was print all (680) cases, but the same syntax can be used later if we take action on them.
# Out:
#          sex pclass  age
# 12    female    1st  NaN
# 13      male    1st  NaN
# 14      male    1st  NaN
# 29      male    1st  NaN
# 32      male    1st  NaN
# 35      male    1st  NaN
# 40      male    1st  NaN
# 45      male    1st  NaN
# 46      male    1st  NaN
# 52    female    1st  NaN
# 54    female    1st  NaN
# 59    female    1st  NaN
# 60      male    1st  NaN
# 61    female    1st  NaN
# 62      male    1st  NaN
# 65      male    1st  NaN
# 66      male    1st  NaN
# 71      male    1st  NaN
# 77      male    1st  NaN
# 81    female    1st  NaN
# 84      male    1st  NaN
# 85    female    1st  NaN
# 96    female    1st  NaN
# 97      male    1st  NaN
# 105     male    1st  NaN
# 107   female    1st  NaN
# 118   female    1st  NaN
# 133     male    1st  NaN
# 137     male    1st  NaN
# 138     male    1st  NaN
# ...      ...    ...  ...
# 1283  female    3rd  NaN
# 1284    male    3rd  NaN
# 1285    male    3rd  NaN
# 1286    male    3rd  NaN
# 1287    male    3rd  NaN
# 1288    male    3rd  NaN
# 1289    male    3rd  NaN
# 1290    male    3rd  NaN
# 1291    male    3rd  NaN
# 1292    male    3rd  NaN
# 1293  female    3rd  NaN
# 1294    male    3rd  NaN
# 1295    male    3rd  NaN
# 1296    male    3rd  NaN
# 1297    male    3rd  NaN
# 1298    male    3rd  NaN
# 1299    male    3rd  NaN
# 1300    male    3rd  NaN
# 1301    male    3rd  NaN
# 1302    male    3rd  NaN
# 1303    male    3rd  NaN
# 1304  female    3rd  NaN
# 1305    male    3rd  NaN
# 1306  female    3rd  NaN
# 1307  female    3rd  NaN
# 1308    male    3rd  NaN
# 1309    male    3rd  NaN
# 1310    male    3rd  NaN
# 1311  female    3rd  NaN
# 1312    male    3rd  NaN
#
# [680 rows x 3 columns]

# %%
# Before we finish the initial investigation, let's use one other convenience function of pandas to derive a 
# histogram of any numerical column. 
import pylab as pyl
df_titanic['age'].hist()
pyl.show()

# %%
# Inside the parentheses of .hist(), you can also be more explicit about options of this function. Before you invoke 
# it, you can also be explicit that you are dropping the missing values of age:
df_titanic['age'].dropna().hist(bins=16, range=(0,80), alpha = .5)
pyl.show()

# %% [markdown]
# ## 3. Data Munging

# %% [markdown]
# ### 3.1. Transform the Data

# %% [markdown]
# Transform the values in the dataframe into the shape we need for machine learning.
#
# First of all, it's hard to run analysis on the string values of "male" and "female".
# Let's store this transformation into a new column 'Gender'. We have a precedent of analyzing the women first, so let's decide female = 0 and male = 1.

# %%
# Let's store our transformation in a new column, so the original sex isn't changed.
df_titanic['Gender'] = 4
df_titanic['Gender'] = df_titanic['sex'].map( {'female': 0, 'male': 1} ).astype(int)
df_titanic.head(3)
# Out:
#    passengers pclass  survived                                 name   age  \
# 0           1    1st         1         Allen, Miss Elisabeth Walton  29.0
# 1           2    1st         0          Allison, Miss Helen Loraine   2.0
# 2           3    1st         0  Allison, Mr Hudson Joshua Creighton  30.0
#
#       embarked                        home/dest room      ticket  boat  \
# 0  Southampton                     St Louis, MO  B-5  24160 L221     2
# 1  Southampton  Montreal, PQ / Chesterville, ON  C26         NaN   NaN
# 2  Southampton  Montreal, PQ / Chesterville, ON  C26         NaN  -135
#
#       sex  Gender
# 0  female       0
# 1  female       0
# 2    male       1

# %%
# Do the same for passenger class, make it numeric, in a new column PClass. 

## Your code ...
df_titanic['PClass'] = 5
df_titanic['PClass'] = df_titanic['pclass'].map( {'1st' : 1, '2nd' : 2, '3rd' : 3} ).astype(int)
df_titanic.head(3)
# Out:
#    passengers pclass  survived                                 name   age  \
# 0           1    1st         1         Allen, Miss Elisabeth Walton  29.0
# 1           2    1st         0          Allison, Miss Helen Loraine   2.0
# 2           3    1st         0  Allison, Mr Hudson Joshua Creighton  30.0
#
#       embarked                        home/dest room      ticket  boat  \
# 0  Southampton                     St Louis, MO  B-5  24160 L221     2
# 1  Southampton  Montreal, PQ / Chesterville, ON  C26         NaN   NaN
# 2  Southampton  Montreal, PQ / Chesterville, ON  C26         NaN  -135
#
#       sex  Gender  PClass
# 0  female       0       1
# 1  female       0       1
# 2    male       1       1

# %%
# Show all males in the second class

## Your code ...
df_titanic[(df_titanic['sex'] == 'female') & (df_titanic['pclass'] == '2nd')]
# Out:
#      passengers pclass  survived  \
# 323         324    2nd         1
# 327         328    2nd         1
# 331         332    2nd         1
# 335         336    2nd         1
# 337         338    2nd         1
# 338         339    2nd         1
# 340         341    2nd         1
# 342         343    2nd         1
# 347         348    2nd         1
# 349         350    2nd         1
# 350         351    2nd         1
# 352         353    2nd         1
# 355         356    2nd         1
# 357         358    2nd         1
# 359         360    2nd         1
# 363         364    2nd         0
# 366         367    2nd         0
# 367         368    2nd         1
# 368         369    2nd         1
# 370         371    2nd         1
# 375         376    2nd         1
# 376         377    2nd         1
# 377         378    2nd         0
# 378         379    2nd         0
# 379         380    2nd         0
# 383         384    2nd         1
# 385         386    2nd         1
# 389         390    2nd         1
# 392         393    2nd         1
# 393         394    2nd         1
# ..          ...    ...       ...
# 541         542    2nd         1
# 542         543    2nd         1
# 545         546    2nd         1
# 547         548    2nd         1
# 549         550    2nd         1
# 552         553    2nd         1
# 553         554    2nd         1
# 554         555    2nd         1
# 555         556    2nd         1
# 557         558    2nd         1
# 560         561    2nd         1
# 565         566    2nd         1
# 567         568    2nd         1
# 568         569    2nd         1
# 570         571    2nd         0
# 573         574    2nd         1
# 575         576    2nd         1
# 578         579    2nd         1
# 579         580    2nd         1
# 580         581    2nd         1
# 582         583    2nd         1
# 583         584    2nd         1
# 584         585    2nd         1
# 586         587    2nd         1
# 587         588    2nd         1
# 589         590    2nd         1
# 594         595    2nd         1
# 596         597    2nd         1
# 597         598    2nd         0
# 599         600    2nd         1
#
#                                                   name   age     embarked  \
# 323                         Abelson, Mrs Samuel (Anna)  28.0    Cherbourg
# 327                   Angle, Mrs William A. (Florence)  32.0  Southampton
# 331                             Balls, Mrs Ada E. Hall  36.0  Southampton
# 335                   Beane, Mrs Edward (Ethel Clarke)  19.0  Southampton
# 337   Becker, Mrs Allen Oliver (Nellie E. Baumgardner)  36.0  Southampton
# 338                         Becker, Miss Marion Louise   4.0  Southampton
# 340                        Becker, Miss Ruth Elizabeth  12.0  Southampton
# 342                            Bentham, Miss Lilian W.  19.0  Southampton
# 347                               Brown, Miss Edith E.  15.0  Southampton
# 349   Brown, Mrs Thomas William Solomon (Elizabeth C.)  40.0  Southampton
# 350                                 Bryhl, Miss Dagmar  20.0  Southampton
# 352                                    Buss, Miss Kate  36.0  Southampton
# 355                              Bystrom, Mrs Carolina  42.0  Southampton
# 357  Caldwell, Mrs Albert Francis (Sylvia Mae Harba...  26.0  Southampton
# 359                                Cameron, Miss Clear  31.0  Southampton
# 363      Carter, Mrs Ernest Courtenay (Lillian Hughes)  44.0  Southampton
# 366          Chapman, Mrs John Henry (Elizabeth Lawry)  30.0  Southampton
# 367                         Christy, Mrs Alice Frances   NaN  Southampton
# 368                                Christy, Miss Julie   NaN  Southampton
# 370                 Clarke, Mrs Charles V. (Ada Maria)   NaN  Southampton
# 375               Collyer, Mrs Harvey (Charlotte Tate)  31.0  Southampton
# 376                             Collyer, Miss Marjorie   8.0  Southampton
# 377                            Cook, Mrs Selena Rogers  22.0  Southampton
# 378              Corbett, Mrs Walter H. (Irene Colvin)  30.0  Southampton
# 379  Corey, Mrs Percy C. (Mary Phyllis Elizabeth Mi...   NaN  Southampton
# 383                                   Davis, Mrs Agnes  49.0  Southampton
# 385                                   Davis, Miss Mary  28.0  Southampton
# 389       del Carlo, Mrs Sebastiano (Argenia Genovese)  22.0    Cherbourg
# 392                                    Doling, Mrs Ada  32.0  Southampton
# 393                                 Doling, Miss Elsie  18.0  Southampton
# ..                                                 ...   ...          ...
# 541         Renouf, Mrs Peter Henry (Lillian Jefferys)  30.0  Southampton
# 542                          Reynaldo, Mrs Encarnacion  28.0  Southampton
# 545               Richards, Mrs Sidney (Emily Hocking)  25.0  Southampton
# 547                                Ridsdale, Miss Lucy  50.0  Southampton
# 549                                   Rugg, Miss Emily  21.0  Southampton
# 552                     Shelley, Mrs William (Imanita)  25.0  Southampton
# 553                                 Silven, Miss Lyyli  18.0  Southampton
# 554                                Sincock, Miss Maude  20.0  Southampton
# 555                               Siukonnen, Miss Anna  30.0  Southampton
# 557                           Slayter, Miss Hilda Mary  30.0   Queenstown
# 560                                 Smith, Miss Marion   NaN  Southampton
# 565                                 Toomey, Miss Ellen  50.0  Southampton
# 567                  Trout, Mrs William H. (Jessie L.)   NaN  Southampton
# 568                          Troutt, Miss Edwina Celia  27.0  Southampton
# 570  Turpin, Mrs William John (Dorothy Anne Wonnacott)  27.0  Southampton
# 573                              Walcroft, Miss Nellie  35.0  Southampton
# 575        Ware, Mrs John James (Florence Louise Long)  28.0  Southampton
# 578                                  Watt, Miss Bertha  12.0  Southampton
# 579              Watt, Mrs James (Bessie Inglis Milne)  40.0  Southampton
# 580                                 Webber, Miss Susan  36.0  Southampton
# 582                      Weisz, Mrs Leopold (Mathilde)  32.0  Southampton
# 583             Wells, Mrs Arthur H. (Addie Trevaskis)  29.0  Southampton
# 584                                   Wells, Miss Joan   4.0  Southampton
# 586                              West, Miss Barbara J.   NaN  Southampton
# 587                        West, Miss Constance Mirium   NaN  Southampton
# 589                   West, Mrs Edwy Arthur (Ada Mary)  33.0  Southampton
# 594                      Wilkinson, Mrs Elizabeth Anne   NaN  Southampton
# 596                                Wright, Miss Marion  26.0  Southampton
# 597                              Yrois, Miss Henriette   NaN  Southampton
# 599                                Brown, Miss Mildred  24.0  Southampton
#
#                                              home/dest   room         ticket  \
# 323                                Russia New York, NY    NaN            NaN
# 327                                   Warwick, England    NaN            NaN
# 331                   Bristol, Avon / Jacksonville, FL    NaN            NaN
# 335                             Norwich / New York, NY    NaN            NaN
# 337                 Guntur, India / Benton Harbour, MI    NaN     230136 L39
# 338                 Guntur, India / Benton Harbour, MI    NaN     230136 L39
# 340                 Guntur, India / Benton Harbour, MI    NaN     230136 L39
# 342                                      Rochester, NY    NaN            NaN
# 347              Cape Town, South Africa / Seattle, WA    NaN            NaN
# 349              Cape Town, South Africa / Seattle, WA    NaN            NaN
# 350                       Skara, Sweden / Rockford, IL    NaN            NaN
# 352             Sittingbourne, England / San Diego, CA    E-?          27849
# 355                                       New York, NY    NaN            NaN
# 357                  Bangkok, Thailand / Roseville, IL    NaN            NaN
# 359                                     Mamaroneck, NY    NaN            NaN
# 363                                             London    NaN            NaN
# 366                             Cornwall / Spokane, WA    NaN            NaN
# 367                                             London    NaN            NaN
# 368                                             London    NaN            NaN
# 370                        England / San Francisco, CA    NaN            NaN
# 375            Bishopstoke, Hants / Fayette Valley, ID    NaN            NaN
# 376            Bishopstoke, Hants / Fayette Valley, ID    NaN            NaN
# 377                                       Pennsylvania   F-33            NaN
# 378                                          Provo, UT    NaN            NaN
# 379                  Upper Burma, India Pittsburgh, PA    NaN            NaN
# 383                    St Ives, Cornwall / Hancock, MI    NaN            NaN
# 385                         London / Staten Island, NY    NaN            NaN
# 389                          Lucca, Italy / California    NaN            NaN
# 392                                        Southampton    NaN            NaN
# 393                                        Southampton    NaN            NaN
# ..                                                 ...    ...            ...
# 541                                      Elizabeth, NJ    NaN            NaN
# 542                                              Spain    NaN            NaN
# 545                               Cornwall / Akron, OH    NaN            NaN
# 547  London, England / Marietta, Ohio and Milwaukee...    NaN            NaN
# 549                          Guernsey / Wilmington, DE    NaN            NaN
# 552                                     Deer Lodge, MT    NaN            NaN
# 553                          Finland / Minneapolis, MN    NaN            NaN
# 554                             Cornwall / Hancock, MI    NaN            NaN
# 555                           Finland / Washington, DC    NaN            NaN
# 557                                        Halifax, NS    NaN            NaN
# 560                                                NaN    NaN            NaN
# 565                                   Indianapolis, IN    NaN            NaN
# 567                                       Columbus, OH    NaN            NaN
# 568                      Bath, England / Massachusetts  E-101  34218 L10 10s
# 570                                  Plymouth, England    NaN            NaN
# 573                                     Mamaroneck, NY    NaN            NaN
# 575                 Bristol, England / New Britain, CT    NaN            NaN
# 578                            Aberdeen / Portland, OR    NaN            NaN
# 579                            Aberdeen / Portland, OR    NaN            NaN
# 580                             England / Hartford, CT  E-101            NaN
# 582                 Bromsgrove, England / Montreal, PQ    NaN            NaN
# 583                               Cornwall / Akron, OH    NaN            NaN
# 584                               Cornwall / Akron, OH    NaN            NaN
# 586                                Bournmouth, England    NaN            NaN
# 587                                Bournmouth, England    NaN            NaN
# 589                                Bournmouth, England    NaN            NaN
# 594                                Manchester, England    NaN            NaN
# 596                Yoevil, England / Cottage Grove, OR    NaN            NaN
# 597                                              Paris    NaN            NaN
# 599                              London / Montreal, PQ   F-33            NaN
#
#     boat     sex  Gender  PClass
# 323   12  female       0       2
# 327  NaN  female       0       2
# 331  NaN  female       0       2
# 335  NaN  female       0       2
# 337   11  female       0       2
# 338   11  female       0       2
# 340   13  female       0       2
# 342   12  female       0       2
# 347   14  female       0       2
# 349   14  female       0       2
# 350   12  female       0       2
# 352    9  female       0       2
# 355  NaN  female       0       2
# 357   13  female       0       2
# 359  NaN  female       0       2
# 363  NaN  female       0       2
# 366  NaN  female       0       2
# 367  NaN  female       0       2
# 368  NaN  female       0       2
# 370   14  female       0       2
# 375   14  female       0       2
# 376   14  female       0       2
# 377   14  female       0       2
# 378  NaN  female       0       2
# 379  NaN  female       0       2
# 383  NaN  female       0       2
# 385   13  female       0       2
# 389  NaN  female       0       2
# 392  NaN  female       0       2
# 393  NaN  female       0       2
# ..   ...     ...     ...     ...
# 541  NaN  female       0       2
# 542  NaN  female       0       2
# 545    4  female       0       2
# 547  NaN  female       0       2
# 549   12  female       0       2
# 552   12  female       0       2
# 553  NaN  female       0       2
# 554   11  female       0       2
# 555  NaN  female       0       2
# 557   13  female       0       2
# 560  NaN  female       0       2
# 565    9  female       0       2
# 567    9  female       0       2
# 568   16  female       0       2
# 570  NaN  female       0       2
# 573  NaN  female       0       2
# 575   12  female       0       2
# 578    9  female       0       2
# 579    9  female       0       2
# 580  NaN  female       0       2
# 582  NaN  female       0       2
# 583  NaN  female       0       2
# 584  NaN  female       0       2
# 586  NaN  female       0       2
# 587  NaN  female       0       2
# 589  NaN  female       0       2
# 594  NaN  female       0       2
# 596    9  female       0       2
# 597  NaN  female       0       2
# 599   11  female       0       2
#
# [107 rows x 13 columns]

# %% [markdown]
# ### 3.2. Deal with Missing Values

# %% [markdown]
# Now it's time to deal with the missing values of age! Why? Simply because most machine learning will need a complete set of
# values in that column to use it. By filling it in with guesses, we'll be introducing some noise into a model, but if we can
# keep our guesses reasonable, some of them should be close to the historical truth (whatever it was...), and the overall
# predictive power of age might still make a better model than before.

# %% [markdown]
# We know the average age of all passengers (with valid age field) is 31.2 - we could fill in the null values with that mean value. But may be the median would be better? (to reduce the influence of a few rare 70- and 80-year olds?) The age histogram did seem positively skewed. These are the kind of decisions you make as you create your models.

# %% [markdown]
# Replace the NaN (unknown) age values with a reasonable estimate. Do this in a new column 'AgeFill'

# %%
average_age = df_titanic['age'].mean()
average_age

df_titanic['AgeFill'] = 6
df_titanic['AgeFill'] = df_titanic['age'].fillna(average_age)
df_titanic.tail(10)
# Out:
#       passengers pclass  survived                    name  age embarked  \
# 1303        1304    3rd         0      Yasbeck, Mr Antoni  NaN      NaN
# 1304        1305    3rd         1     Yasbeck, Mrs Antoni  NaN      NaN
# 1305        1306    3rd         0      Youssef, Mr Gerios  NaN      NaN
# 1306        1307    3rd         0     Zabour, Miss Hileni  NaN      NaN
# 1307        1308    3rd         0     Zabour, Miss Tamini  NaN      NaN
# 1308        1309    3rd         0      Zakarian, Mr Artun  NaN      NaN
# 1309        1310    3rd         0  Zakarian, Mr Maprieder  NaN      NaN
# 1310        1311    3rd         0         Zenn, Mr Philip  NaN      NaN
# 1311        1312    3rd         0           Zievens, Rene  NaN      NaN
# 1312        1313    3rd         0          Zimmerman, Leo  NaN      NaN
#
#      home/dest room ticket boat     sex  Gender  PClass    AgeFill
# 1303       NaN  NaN    NaN  NaN    male       1       3  31.194181
# 1304       NaN  NaN    NaN  NaN  female       0       3  31.194181
# 1305       NaN  NaN    NaN  NaN    male       1       3  31.194181
# 1306       NaN  NaN    NaN  NaN  female       0       3  31.194181
# 1307       NaN  NaN    NaN  NaN  female       0       3  31.194181
# 1308       NaN  NaN    NaN  NaN    male       1       3  31.194181
# 1309       NaN  NaN    NaN  NaN    male       1       3  31.194181
# 1310       NaN  NaN    NaN  NaN    male       1       3  31.194181
# 1311       NaN  NaN    NaN  NaN  female       0       3  31.194181
# 1312       NaN  NaN    NaN  NaN    male       1       3  31.194181

# %% [markdown]
# #### Now it is your turn. Use the mean age of male and female for each passenger class

# %% [markdown]
# ### 3.3 Hot Encoding

# %% [markdown]
# We have a categorical feature attribute: pclass. We already converted its three classes into 0, 1, and 2. This transformation implicitly introduces an ordering.
#
# As a final step, we will try a more general approach that does not assume an ordering. This is widely used to convert categorical classes into real-valued attributes. We will introduce an additional encoder and convert the class attributes into three new binary features, each of them indicating if the instance belongs to a feature value (1) or (0). This is called one hot encoding, and it is a very common way of managing categorical attributes for real-based methods.

# %%
df_titanic['FirstClass'] = df_titanic['pclass'].map( {'1st': 1, '2nd': 0, '3rd': 0} ).astype(int)
df_titanic['SecondClass'] = df_titanic['pclass'].map( {'1st': 0, '2nd': 1, '3rd': 0} ).astype(int)
df_titanic['ThirdClass'] = df_titanic['pclass'].map( {'1st': 0, '2nd': 0, '3rd': 1} ).astype(int)

df_titanic.head(5)
# Out:
#    passengers pclass  survived  \
# 0           1    1st         1
# 1           2    1st         0
# 2           3    1st         0
# 3           4    1st         0
# 4           5    1st         1
#
#                                               name      age     embarked  \
# 0                     Allen, Miss Elisabeth Walton  29.0000  Southampton
# 1                      Allison, Miss Helen Loraine   2.0000  Southampton
# 2              Allison, Mr Hudson Joshua Creighton  30.0000  Southampton
# 3  Allison, Mrs Hudson J.C. (Bessie Waldo Daniels)  25.0000  Southampton
# 4                    Allison, Master Hudson Trevor   0.9167  Southampton
#
#                          home/dest room      ticket  boat     sex  Gender  \
# 0                     St Louis, MO  B-5  24160 L221     2  female       0
# 1  Montreal, PQ / Chesterville, ON  C26         NaN   NaN  female       0
# 2  Montreal, PQ / Chesterville, ON  C26         NaN  -135    male       1
# 3  Montreal, PQ / Chesterville, ON  C26         NaN   NaN  female       0
# 4  Montreal, PQ / Chesterville, ON  C22         NaN    11    male       1
#
#    PClass  AgeFill  FirstClass  SecondClass  ThirdClass
# 0       1  29.0000           1            0           0
# 1       1   2.0000           1            0           0
# 2       1  30.0000           1            0           0
# 3       1  25.0000           1            0           0
# 4       1   0.9167           1            0           0

# %% [markdown]
# ## 4. Preprocessing

# %% [markdown]
# Let's start with feature selection

# %%
titanic_X = df_titanic[['AgeFill','Gender','FirstClass','SecondClass','ThirdClass']]
titanic_y = df_titanic['survived']

# %%
titanic_X.head(10)
# Out:
#    AgeFill  Gender  FirstClass  SecondClass  ThirdClass
# 0  29.0000       0           1            0           0
# 1   2.0000       0           1            0           0
# 2  30.0000       1           1            0           0
# 3  25.0000       0           1            0           0
# 4   0.9167       1           1            0           0
# 5  47.0000       1           1            0           0
# 6  63.0000       0           1            0           0
# 7  39.0000       1           1            0           0
# 8  58.0000       0           1            0           0
# 9  71.0000       1           1            0           0

# %%
titanic_y.head(10)
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# 5    1
# 6    1
# 7    0
# 8    1
# 9    0
# Name: survived, dtype: int64

# %% [markdown]
# Now split the data into train and test

# %%
from sklearn.model_selection import train_test_split

X_train_titanic, X_test_titanic, y_train_titanic, y_test_titanic = train_test_split(titanic_X, titanic_y, test_size=0.2, random_state = 42)

# %% [markdown]
# ## 5. Modeling

# %% [markdown]
# The preprocessing step is usually under-estimated in machine learning methods, but as we can see even in this very simple example, it can take some time to make data look as our methods expect. It is also very important in the overall machine learning process; if we fail in this step (for example, incorrectly encoding attributes, or selecting the wrong features), the following steps will fail, no matter how good the method we use for learning!!
#
# We are now ready for the implementation of decision trees in scikit-learn, as this algo expects as input a list of
# real-valued features, and the decision rules of the model would be of the form: Feature < value.
# For example, AgeFill < 20.0.
#
# Standardization (normalization) is not an issue for decision trees because the relative magnitude of features does not
# affect the classifier performance; so scaling is not needed.

# %% [markdown]
# ### 5.1. Training a Decision Tree Classifier

# %% [markdown]
#  Now, we can create a new DecisionTreeClassifier and use the fit method of the classifier to do the learning job.
#  Parameter settings: use the entropy citerion and try out different settings for the depth of the tree and the
#  minimum samples required for a node in the tree graph

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_split=2, random_state = 42)
tree_clf.fit(titanic_X,titanic_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %% [markdown]
# ### 5.2. Evaluation Metrics Function

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

y_pred = tree_clf.predict(X_test_titanic)
accuracy_score(y_test_titanic, y_pred)
# Out:
# 0.8250950570342205

# %% [markdown]
# ### 5.3. Keep age as the only feature and run decision tree classification again. Compare the evaluation

# %% [markdown]
# ### 5.4. Add embarked as the new feature with one hot encoding. Run the decision tree classification again. Compare the evaluation. Do you believe the model has been improved? Why?

# %% [markdown]
# ## 6. Introducing Random Forest

# %% [markdown]
# A common criticism to decision trees is that once the training set is divided after
# answering a question, it is not possible to *reconsider this decision*. For example, if
# we divide men and women, every subsequent question would be only about men or
# women, and the method could not consider another type of question (say, age less
# than a year, irrespective of the gender). Random Forests try to introduce some level
# of randomization in each step, proposing alternative trees and combining them to
# get the final prediction. These types of algorithms that consider several classifiers
# answering the same question are called **ensemble methods**. In the Titanic task, it is
# probably hard to see this problem because we have very few features, but usually
# a case has in the order of thousand(s) features.

# %% [markdown]
# Random Forests propose to build several decision trees, each one based on a subset of the training
# instances (selected randomly), and using a small random number of features.
# This produces multiple classifiers (multiple decision trees).
# At prediction time, each grown tree, given an instance, predicts its target class exactly as decision trees do.
# The class that most of the trees vote (that is the class most predicted by the trees) is the one suggested by the ensemble classifier.

# %% [markdown]
# ## 7. Implement Random Forest

# %% [markdown]
# Implement a Random Forest classifier. Can you improve to above accuracy? Look at the sklearn documentation. Play with the parameters of the ``RandomForestClassifier``. Especially the parameter ``n_estimators`` (the number of trees in the forest) is of interest.

# %%
from sklearn.ensemble import RandomForestClassifier

forest_clf = RandomForestClassifier(criterion='entropy', max_depth=2, min_samples_split=2, random_state = 42, n_estimators = 30)
forest_clf.fit(titanic_X,titanic_y)
y_pred = forest_clf.predict(X_test_titanic)
accuracy_score(y_test_titanic, y_pred)
# Out:
# C:\Users\882571\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# 0.8174904942965779
